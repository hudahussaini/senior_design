# %%
import os
os.environ ["TAVILY_API_KEY"] = "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"

# %%
from langchain_community.document_loaders import PyMuPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

pdf_files = [
"/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/10256018808623883.pdf",
"/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/1104.4580.pdf",
"/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/1536867X19893615.pdf"
]
# Function to load and process each PDF
def load_pdfs(pdf_list):
    documents = []  # To store the loaded document objects
    for pdf_path in pdf_list:
        # Initialize the loader for the current PDF
        loader = PyMuPDFLoader(file_path=pdf_path)
        # Load the data from the PDF
        docs = loader.load()
        documents.extend(docs)  # Append loaded documents to the list
    return documents

# Process the PDF files
all_documents = load_pdfs(pdf_files)

# Print out the content of each document
for doc in all_documents:
    print(f"Document Metadata: {doc.metadata}")
    print(f"Document Content:\n{doc.page_content}")
    print("-" * 40)
# Out:
# Document Metadata: {'source': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/10256018808623883.pdf', 'file_path': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/10256018808623883.pdf', 'page': 0, 'total_pages': 9, 'format': 'PDF 1.4', 'title': 'Computer-aided INAA Measurements and Geochemical Classification of Various Basaltic Rocks from Costa', 'author': '', 'subject': '', 'keywords': '', 'creator': 'ABBYY FineReader', 'producer': '', 'creationDate': "D:20080229114210+05'30'", 'modDate': "D:20080229114213+05'30'", 'trapped': ''}
# Document Content:
# Isotopenpraxis Isotopes in Environmental and Health
# Studies
# ISSN: 0021-1915 (Print) (Online) Journal homepage: www.tandfonline.com/journals/gieh19
# Computer-aided INAA Measurements and
# Geochemical Classiﬁcation of Various Basaltic
# Rocks from Costa Rica
# G. Just, E.-J. Langrock, V. H. Chanto Arguedas, S. Kussmaul & W. D. Fromm
# To cite this article: G. Just, E.-J. Langrock, V. H. Chanto Arguedas, S. Kussmaul & W. D. Fromm
# (1988) Computer-aided INAA Measurements and Geochemical Classiﬁcation of Various Basaltic
# Rocks from Costa Rica, Isotopenpraxis Isotopes in Environmental and Health Studies, 24:1,
# 6-13, DOI: 10.1080/10256018808623883
# To link to this article:  https://doi.org/10.1080/10256018808623883
# Published online: 08 Sep 2008.
# Submit your article to this journal
# Article views: 5531
# View related articles
# Full Terms & Conditions of access and use can be found at
# https://www.tandfonline.com/action/journalInformation?journalCode=gieh20
#
# ----------------------------------------
# Document Metadata: {'source': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/10256018808623883.pdf', 'file_path': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/10256018808623883.pdf', 'page': 1, 'total_pages': 9, 'format': 'PDF 1.4', 'title': 'Computer-aided INAA Measurements and Geochemical Classification of Various Basaltic Rocks from Costa', 'author': '', 'subject': '', 'keywords': '', 'creator': 'ABBYY FineReader', 'producer': '', 'creationDate': "D:20080229114210+05'30'", 'modDate': "D:20080229114213+05'30'", 'trapped': ''}
# Document Content:
# Just ct al.: Classification of Various Basnltic Kocks from Costa Rica
# Isotopcnpraxis 21 (1988) 1, pp. C —13
# Computer-aided INAA Measurements and Gcocliemical Classification
# of Various Basaltic Rocks from Costa Rica
# G. Just
# Karl-Marx-Univcrsitat Leipzig, Sektion Physik, Fachbereich Geophysik, Talstr. 35, DDR-7010 Leipzig
# E.-J. Langroch
# Teclmische Hochschulo Leipzig, Sektion Naturwissenschaften, Karl-Liobknecht-Str. 132, DDR-7030 Leipzig
# V. H. Chanto Arguedas, S. Kussmaul
# Universidad de Costa Rica, San Jose
# W. D. Fromm
# AkademiederWissonschaftenderDDR, Zentraliustitut fur Kernforschung, Postschliefifach 19, DDR-8051 Dresden/
# Rossendorf
# The basaltic rocks of Costa Rica show a wide range of chemical compositions. By means of INAA measurements a cor-
# relation matrix has been derived and there ia a positive correlation of the REE and Th with U, Hf, Ta and Rb in basaltic
# rocks and a negative correlation of the REE with Co, Sc, Cs and Fe.
# Die chemischeZusammensetzung basaUischer Gesteine aus Costa Rica variiert in einem weiten Bereich: Auf derGrund-
# lage von Ergebnissen der INAA wurde eine Korrelationsmatrix erslellt. Es icurde eine positive Korrelalion der SEE und
# Th mit U, Hf, Ta und Rb gefunden. FiXr die SEE gegeniiber Co, Sc, Cs und Fe ergibt sich eine negative Korrelation.
# Keywords
# basalt, costa rica, geochemistry, geologic surveys, neutron activation analysis, rare earths, thorium, uranium
# 1.
# Introduction
# 1.1. Analytical
# Only within the last 20 years has trace element geochemistry
# become an important field in mineralogy and petrology. Neu-
# tron activation along with isotope dilution by massspectro-
# metry and X-ray fluorescence are the principal techniques
# used for the traco element analysis of rocks and minerals.
# The importance of the neutron activation in studying
# small and precious geological samples has been clearly
# indicated in tho analysis program for lunar samples.
# Sorao main elements, such as Al, Na, Mn and Fe, can be
# readily determined by the instrumental neutron activation
# analysis (INAA), but several other main elements, e.g.,
# Mg and Ca, cannot be readily determined by this method.
# In fact, by combining neutron activation investigations
# with the method of tho X-ray fluorescence analysis, a
# wide variety of main and trace elements can bo determined
# in rocks and minerals.
# Tho neutron activation analysis (NAA) is mainly applied
# in traco element geochemistry (o.g. [1]). Winchester [2]
# has compared tho sensitivity of NAA to typical element
# abundances in rocks and has shown, that about CO ele-
# ments can bo analysed by NAA. A particularly useful
# aspect of tho NAA-method is its flexibility to utilize INAA
# for samples with a relatively high content of trace elements
# (e.g., granites and alkaline basalts [3]) and some radiochem-
# ical techniques for samples with a relatively low content
# of trace elements (e.g., peridotites, meteorites).
# In fractional crystallization and low-pressure melting
# processes tho abundanco of Sr is useful for indicating tho
# rolo of plagioclase, and abundances of Rb and Ba are useful
# for indicating the rolo of potassium feldspar and mica. The
# INAA method is tho most acceptable procedure in deter-
# mining these elements in granitic rocks and alkaline basalts
# where they are relatively abundant.
# Some data for ocean floor basalts obtained by isotope
# dilution show that tho abundanco of Cs is a very sensitive
# monitor of low-temperature alterations. A potentially
# interesting application arises from Cs data obtained for
# batholithes from the south-eastern part of Australia [3].
# Granites derived from sedimentary source rocks have a
# higher content of Cs than those derived from igneous source
# rocks. In the southern part of the GDR (Variscan granitic
# series) the content of Cs ranges from 2 to 100 ppm as stated
# by Just [4, 5].
# Other investigators have found that Cs is depleted in
# high-grade metamorphic rocks as compared with lower-
# grade rocks such as amphibolites.
# Tho elements So, Cr, Fe and Co can be determined in
# most of the rocks by INAA, and they all can bo readily
# incorporated into mafic minerals such as olivine and/or
# pyroxenes quickly. Thus, during the basalt potrogenesis,
# they are commonly described as compatible element abun-
# dances in liquids during fractional crj'stallizntion. Jlclts
# G
# Iaotopenpraxis 21 (19SS) 1
#
# ----------------------------------------
# Document Metadata: {'source': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/10256018808623883.pdf', 'file_path': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/10256018808623883.pdf', 'page': 2, 'total_pages': 9, 'format': 'PDF 1.4', 'title': 'Computer-aided INAA Measurements and Geochemical Classification of Various Basaltic Rocks from Costa', 'author': '', 'subject': '', 'keywords': '', 'creator': 'ABBYY FineReader', 'producer': '', 'creationDate': "D:20080229114210+05'30'", 'modDate': "D:20080229114213+05'30'", 'trapped': ''}
# Document Content:
# Just ct al.: Classification of Various Basaltic Rocks from Costa Rica
# derived from a single homogeneous source of varying de-
# grees of melting aro expected to have relatively constant
# abundances of compatible elements.
# In many rocks the elements Hf and Ta can bo determined
# to a good accuracy, even by INAA. Thcro are three main
# types of geoehemieal applications of abundance data for
# these elements
# — good indication of tho degree of crystallization
# — the pairs Zr-Hf and Nb-Ta have very similar ionic radii
# and similar geoehemieal behaviour and, therefore, their
# abundance ratios cannot bo easily changed by geological
# processes
# — abundances of Hf, Ta and Th aro useful in distinguish-
# ing basalts from different tectonic settlings.
# INAA is suitable for determining tho rare-earth elements
# (REE) in granites and in most of tho basalts, and using
# radiochemical NAA, REE can also be determined in mine-
# rals such asolivino and feldspars. REE abundanco data
# havo proven very useful in trace element geochemistry
# because of the geoehemieal coherence of REE. Under most
# of the terrestrial conditions they occur in the + 3 oxidation
# state, and their goochemical behaviour is largely controlled
# by tho small bvit systematic differences in ionic radius. In
# the last 20 years considerable progress has been made in un-
# derstanding how various petrogenetic processes affect REE
# abundances, and recently, some publishers havo reviewed
# some applications of REE geochemistry to a wide variety of
# geological problems. An important tool has been developed
# by F.A. Frey "Applications NAA in Mineralogy and Petro-
# logy" [1].
# With respect to alkaline basalts, continental and island
# tholeiites aro characterized by lower relative enrichments
# of light REE (LREE) and also by lower ratios of light REE
# to heavy REE as compared with alkaline basalts. As Eu
# is preferentially enriched in feldspars, the REE abundances
# havo also been used to evaluate the role of low-pressure
# fractional crystallization in generating tholeitic suites and
# highly differentiated rocks from a basaltic parent rock. An
# extensivo low-pressure fractional crystallization is generally
# reflected by an increase in REE abundances except for Eu,
# which causes a negative Eu anomaly. Tho interest in basal-
# tic rocks recovered from the ocean floor is quite actual. Stu-
# dies are conveniently divided into two eras: a pre-sea-floor
# spreading and a post-soa-floor spreading. Before sea-floor
# spreading was recognized, basalts from oceanic islands, sea-
# mounts and ridges has been thought to erupt through tho
# older oceanic crust. The abundance of ocean ridge basalt in
# the oceanic crust has been greatly underestimated.
# Oceanic tholeiite magmas were classified by tectonic
# settling, tho main distinction being between those erupting
# at oceanic ridges (constructive plate magmas) and those
# erupting through tho thickened oceanic lithosphero (intra-
# 'plate magmas, e.g., Hawaii). Significant geoehemieal diffe-
# rences were found between low-K tholeiites from Hawaii
# and those from tho ocean ridges. Tho Iceland "hot spot"
# or "plume" is a particularly informative area. Tho inter-
# action between tho oceanic crust and tho continental plate
# is of important interest and all tho basaltic rocks from the
# Costa Rica region should bo investigated by means of
# modern nuclear analytical methods. In the first series,
# 13 alkaline rocks and tholeiitic basalts together with somo
# andesites from the region were analyzed.
# Tho geological position of somo of tho samples is shown
# in Fig. 1.
# OCEANO ATLANTICO
# Fig. 1. Position of basaltic and andesitic rocks from Costa Iliea
# Isotopenpraxis 21 (19SS) 1
#
# ----------------------------------------
# Document Metadata: {'source': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/10256018808623883.pdf', 'file_path': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/10256018808623883.pdf', 'page': 3, 'total_pages': 9, 'format': 'PDF 1.4', 'title': 'Computer-aided INAA Measurements and Geochemical Classification of Various Basaltic Rocks from Costa', 'author': '', 'subject': '', 'keywords': '', 'creator': 'ABBYY FineReader', 'producer': '', 'creationDate': "D:20080229114210+05'30'", 'modDate': "D:20080229114213+05'30'", 'trapped': ''}
# Document Content:
# Just et al.: Classification of Various Basaltic Rocks from Costa Rica
# 1.2.
# Main elements of geology
# The South American landmass consists of a craton, which
# was created during tho Brazilian orogenesis in the Late
# Precambrian; it is mostly covered with unfolded younger
# sediments and effusive rocks. There are intrusives of various
# ages in both tho craton and its cover.
# Along the Pacific coast tho situation is different. Hero
# tho craton is bounded by tho Cordilleras, an orogenic fold
# belt, which runs from the North to the South. This belt,
# which contains remnants of Palaeozoic orogens, was main-
# ly created by the relative movement of tho continent
# towards tho West during tho Late Mesozoic and Tertiary,
# which resulted in underthrusting. Volcanism is widespread
# throughout tho Cordilleras and is still continuing in certain
# areas.
# Towards th6 North, in Central America, tho Cordilleras
# continuo in remnants and aro a link to tho North American
# continent though tho different movements of tho two land
# masses have caused, and still cause, various twists and
# breaks. Tho situation here is complicated due to branching-
# off of tho easternmost ranges in an easterly direction (from
# North Venezuela to Trinidad) thus apparently establish-
# ing a link to an equatorial (Alpine) fold belt.
# The Cordilleras, though appearing geographically as a
# unit and having a common cause of their origin, present a
# rather complicated geological picture. A conclusive ana-
# lysis of these areas has not been attempted yet.
# Basically, tho Cordilleras can be divided into two parts:
# — a northern part, reaching from Central America to,
# approximately, tho Peru-Chile border
# — a southern part, reaching from this border toCapeHoorn.
# Though most of tho rocks exposed in the Cordilleras are
# from tho Mesozoic and Tertiary, remnants of older rocks
# and older orogenic events aro present in both parts.
# A western branch of tho Cordilleras extends through
# Panama, Costa Rica and Nicaragua. This branch consists
# of oceanic crustal rocks including ultrabasic rocks, mafic
# pillow lavas and marine sediments, in particular, grey-
# wackes of tho pro-Upper Cretaceous. These rocks have
# intruded by gabbro diorite-quartz diorite pluton. Tertiary
# volcanism, mainly tho andesitic one at first, which then
# became siliceous and alkaline, occured in many places, and
# volcanoes are still active in certain areas. Marine sedimen-
# tary and volcanic rocks of Tertiary fill basins towards the
# east. Stocks, dykes and sills of andesitic and dacitic compo-
# sition aro common.
# Tho Central American volcanic chain is tho result of
# convergence between tho Cocos and Caribbean plates. The
# volcanic front is divided into eight segments separated by
# zones of transverse faulting and offsets and changes in
# striko and dip of the seismic zone. Tho active volcanoes
# were preceded by an earlier Quartenary volcanic front and
# several pulses of volcanic acitvity during tho Tertiary.
# The Quaternary lavas and pyroelastic rocks havo mine-
# ralogical and chemical characteristics typical of calc-
# alkali rocks. At most of tho volcanoes there are continuous
# fractionation trends from tho abundance, high-alumina
# basalts and basaltic andesites to rare dacites.
# Tho Quaternary volcanic chain in Central America ex-
# tends from the Guatemala-Mexico border to central Costa
# Rica, a distanco of 1100 km. The southeastern end of tho
# chain in central Costa Rica approximately coincides with
# a proposed fracture zone marking the edge of tho Cocos
# plate.
# It is clear that tho interaction between tho Cocos plate
# and Caribbean plato produces a pattern and rate of volcanic
# activity in Central America which aro quite different, from
# these produced by the Cocos plate North—America plate
# convergence in Mexico. Tho Central American volcanic
# belt is, therefore, tho result of plate convergence bound to
# the north-west by a transform zone cutting the overrid-
# ing plato and bound to the south-east by a transform zone
# cutting the underthrusting plate.
# There aro petrologically distinct groups of recent vol-
# canoes in Central America which occur in three distinct
# structural settlings:
# — The volcanic front is the narrow zone of volcanism, and
# the calcalkaline volcanic centres of the front are pri-
# marily basaltic to andesitic composites.
# — The second structural settling for volcanoes in Central
# America is tho region which is immediately landward
# from the volcanic front and adjacent to tho transverse
# breaks. Hero quartz and olivina normative basalts and
# basaltic andesites are often common and nephelino
# normative basalts aro present, too. These volcanoes
# are concentrated in zones of normal faulting near sever-
# al transverse breaks and appear to be related to zones
# of crustal thinning which are common near tho trans-
# verso breaks.
# — The third structural settling is far behind the volcanic
# front, where strongly undersaturated lavas have erupt-
# ed from small scoria cones.
# Most of the volcanic products and all tho historic eruptions
# are duo to the volcanic front, which is clearly the centre of
# volcanic activity in Central America.
# 2.
# Analytical method
# The INAA has proved to be very satisfactory in various
# tests for rapidly classifying magmatic rock complexes.
# By following a standard procedure consisting of one or two
# irradiations in a reactor flux and the measurement of the
# resulting gamma-ray spectrum at threo or four decay times,
# the concentrations of some 20...40 elements can bo deter-
# mined. These elements usually include seven or eight of
# the REE, then Na, K, Rb, Cs, Fe, Sc, Co, Ta, Th, TJ, Sb,
# Hf, Zr as well as As, YV, Au, Ir, Zn, Cu and several other
# elements. Some of these elements or groups of elements
# show some characteristic variations and can bo used as
# sensitive petrogenetic indicators.
# From this it is evident, that the use of INAA for the
# collection of data may be combined with model recogni-
# tion techniques to provide a particularly powerful method
# for studying geochemical variations and for classifying
# unknown samples. First results of the magmatic evolution
# in the Variscan granitic rocks aro given by Just [4] and Just
# et al. [6].
# The analyses of basaltic rocks can bo performed by means
# of an automated measuring system at a relatively low
# expenditure of costs and time.
# Tho measurements wero performed by means of the
# ROBOTRON KRS 4201 (minicomputer) described in
# [7 b]. The spectroscopic apparatus consists of NIM-modules
# (amplifier, analog-to-digital converter and an interface
# unit). Tho data wero presented as parallel words to the
# fast incremental channel of the minicomputer. Tho neces-
# sary dead time correction was performed by means of gate
# CAMAC-eounters. Each of tho spectra of 409G channels is
# 8
# Isotopeuprnxis 24 (1DS8) 1
#
# ----------------------------------------
# Document Metadata: {'source': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/10256018808623883.pdf', 'file_path': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/10256018808623883.pdf', 'page': 4, 'total_pages': 9, 'format': 'PDF 1.4', 'title': 'Computer-aided INAA Measurements and Geochemical Classification of Various Basaltic Rocks from Costa', 'author': '', 'subject': '', 'keywords': '', 'creator': 'ABBYY FineReader', 'producer': '', 'creationDate': "D:20080229114210+05'30'", 'modDate': "D:20080229114213+05'30'", 'trapped': ''}
# Document Content:
# Just et al.: Classification of Various Basaltic Rocks from Costa Rica
# written for disk storage together with the time informa-
# tion. The dead time corrected (and also neutron flux-
# corrected) measurement time is chosen by tho operator
# proportional to tho samples weight. In this manner tho
# activity fluctuations caused by mass differences are com-
# pensated.
# About 120 spectra can be stored on one side of the
# magnetic disk cartridge. AVhilo the measurements are
# being carried out, a rapid evaluation of the spectra by
# means of an automatic peak search program can bo per-
# formed.
# Tho analytical conditions of the computer aided INAA
# measurements and the trace eleme'ht values in tho given
# standard rock samples BM and GM are shown in Tab. 1.1,
# and tho results of many other measurements (LUNA 24
# sample), in Tab. 1.2.
# Tab. 1.1. Analytical conditions of the computer-aided IXAA measurements and the element values in the two given
# standard rocks BM (basaltic rock, Mellenbach, GDR) and GM (granitic rock, MeiBen, GDR)
# !
# La
# Ce
# Nd
# Sm
# Eu
# Tb
# Yb
# Lu
# Th
# U
# Co
# Cs
# Hf
# Sc
# lib
# Fe
# Ta
# Da
# Ag
# As
# Au
# Br
# Cr
# Mo
# Xi
# Sb
# Sn
# Sr
# W
# Zn
# Zr
# BM
# 8-2
# 180
# 170
# 3-G
# 1-2
# 0-72
# 2 1 9
# 0-45
# 2-4
# 0-73
# 0-47
# 2 1
# 2-95
# 3-4
# 100
# 10-2
# 0-22
# 2400
# 0 1
# 140
# 0-9
# 0-55
# 1130
# 0-54
# 4 9 0
# 2G
# 2-5
# 2190
# 0-7
# GM
# 37-0,
# 74-0
# 320
# 4-4
# OGG
# 002
# 2G2
# 0.45
# 33-1
# 7-53
# 2-73
# 7-C
# 7-75
# 4-42
# 2560
# 201
# 1-56
# 3240
# 009
# 4-2
# 1-0
# 1-3G
# 9-5
# 1-33
# 4-4
# 0-56
# 3-6
# 1300
# 1-12
# 42-0
# 1500
# nuclear
# transitions
# ' " L a
# •'•Co
# " ' N d
# •"Sin
# »'Eu
# •"Tb
# •"Yb
# •"Lu
# "•Pa
# •"Xp
# "Co
# •"Cs
# "•IH
# "Sc
# " R b
# " F c
# "•Ta
# •"Ba
# """Ag
# " A s
# "•Au
# ••Br
# "Cr
# "Mo
# "Co
# "'Sb
# "•Sn
# "Sr
# •"\V
# "Zn
# " Z r
# half-life
# period
# 40-2 h
# 32-5 d
# 111 d
# 46-8 d
# 12-0 y
# 72-1 d
# 30-7 d
# G-8 d
# 27-0 d
# 2-4 d
# 5-3 y
# 2-1 y
# '
# 42-5 d
# 840 d
# 18-7 d
# 451 d
# 115-0 d
# 120 d
# 2530 d
# 26-4 h
# 2-7 d
# 35-5 h
# 27-7 d
# 67-0 k
# 70-8 A
# 2-7 d
# 115-0 d
# 680 d
# 23-8 h
# 244-0 d
# Gl-0 d
# yenergy
# [kcY]
# 1597
# 145
# 531
# 103
# 1408
# 879/9GG
# 177
# .
# 208
# 312
# 278
# 1333
# 797
# 482
# 889
# 1077
# 1099
# 1222
# 496
# 658
# 559
# 412
# 777
# 320
# 140
# 811
# 564
# 392
# 513
# 686
# 1115
# 757
# cooling
# period
# 10 d
# 30 d
# 20 d
# .
# 10 d
# 30 d
# 30 d
# 30 d
# 10 d
# 20 d
# 10 d
# 30 d
# 30 d
# 30 d
# 30 d
# 20 d
# 30 d
# 30 d
# 20 d
# 30 d
# 10 d
# 10 d
# 10 d
# 30 d
# 10 d
# 30 d
# 10 d
# 30 d
# 30 d
# 10 d
# 30 d
# 30 d
# interferences
# '"U-fission
# '"U-fission, "Fe
# •"Sm, "Ca
# "•Xp
# "Sc, "'Eu
# •"Ta
# "•Xp
# "Fe,
# '"U-fission
# "'Cs
# •"Tb
# 511 koV
# " ' E u , "°Tb, "So
# •"U-fission
# (Fc in percent FCjO,, and all the other values in ppm)
# Tab. 1.2. Some results from the IXAA measurement under two irradiation conditions (without and with Cd) using the Ge(Li)-detector or
# Gc-X-ray-detector for the LUNA 24 sample (content in ppm, only Ca and Fe in %)
# 31 cm" Ge(Li)
# Ge-X-ray
# 1 0 " n l h/cm'
# 1 0 " nep
# Ca
# Sc
# Fo
# Co
# Br
# Sr
# Ba
# La
# Cc
# Xd
# Sm
# Eu
# Tb
# Tm
# Yb
# Hf
# Ta
# IV
# Th
# —
# 431
# 15-8%
# 5S-0
# 0-5
# —
# —
# 3-7
# 7-1
# —
# 1-52
# 0G9
# 0-39
# —
# 1-2
# 1-5
# -
# 0-22
# —
# 44-9
# 15-7 "A
# 57-2
# 0-5
# 81
# 35
# 3-7
# 5-5
# —
# 1-01
# 0-72
# 0-37
# —
# —
# 1-2
# 0-13
# 0-2G
# 0-29
# 7-2%
# 1.5-9%
# G-5
# 8 1
# 002
# 0-37
# 0-24
# 1-G
# 1-2
# 012
# GC%
# 15-
# oo
# 37
# 5-
# 8-
# 0-
# 0-
# 0-
# 1-
# 1-
# 0-
# 0-
# 0-
# 6»i
# 5
# 1
# 67
# 37
# 23
# 45
# 35
# 13
# 33
# 36
# Isotopenpraxis 21 (1988) 1
#
# ----------------------------------------
# Document Metadata: {'source': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/10256018808623883.pdf', 'file_path': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/10256018808623883.pdf', 'page': 5, 'total_pages': 9, 'format': 'PDF 1.4', 'title': 'Computer-aided INAA Measurements and Geochemical Classification of Various Basaltic Rocks from Costa', 'author': '', 'subject': '', 'keywords': '', 'creator': 'ABBYY FineReader', 'producer': '', 'creationDate': "D:20080229114210+05'30'", 'modDate': "D:20080229114213+05'30'", 'trapped': ''}
# Document Content:
# Just et al.: Classification of Various Basaltic Rocks from Costa Rica
# Tho specific evaluation of the measured samples is per-
# formed in a typical manner after a series of recorded spec-
# tra. Tho FORTRAiST-program AUDK contains as a data
# baso up to 20 elements in tho standard sample and up to
# 50 transition energies of interest, corresponding to the
# decay timo of these elements.
# The positions of the gamma lines in tho spectra give tho
# energy calibration data. Each series of spectra is porceded
# by tho corresponding standard sample. The activity values
# found in tho analysis of the standard sample are internally
# stored and the results of tho unknown spectra arc presented
# as abundances with tho corresponding errors.
# By analyzing only tho interesting peaks and presenting
# only the relevant data, tho analyzing speed and tho volume
# of output aro optimized.
# Tho contents of tho most important peaks can be output
# in a machinereadablo form and thus transferred to a main
# frame computer to achieve a more highly sophisticated
# data analysis. For example, Tab. 1.3 shows tho output of
# tho standard rock and two samples.
# Tab. 1.3. Output of the IXAA measurements with the standard rock 2 GMand two samples (red gneisses, GDIt) 7, 9 and 12 days after the irradiation
# PEAKS
# NUCLIDE
# ENERGY
# CHANNEL
# CONTEXT 2 GM
# SPECTRUM
# AREA 2 GM
# SPECTRUM
# AREA
# CONTENT
# ERROR
# SPECTRUM
# AREA
# CONTENT
# ERROR
# SPECTRUM
# AREA 2 GM
# SPECTRUM
# AREA
# CONTENT
# ERROR
# SPECTRUM
# AREA
# CONTENT
# ERROR
# SPECTRUM
# AREA 2 GM
# SPECTRUM
# AREA
# CONTENT
# ERROR
# SPECTRUM
# AREA
# CONTENT
# ERROR
# 1
# La
# 329
# 9G3
# 7 4 0
# 1
# 10G72
# 1932
# 13-39
# 0-74
# 3
# 1G54
# 11-47
# 0 0 2
# 1
# 14151
# 2
# 2438
# 12-75
# 0-56
# 3
# 1789
# 9-36
# 0-49
# 1
# 3 520
# 2
# 018
# 130
# 1-35
# 3
# 490
# 10-30
# 1 12
# TEFF
# TEFF
# TEFF
# TEFF
# TEFF
# TEFF
# TEFF
# TEFF
# TEFF
# 2
# Sm
# 103
# 313
# 8-8
# 517
# 49437
# 199
# 13831
# 2-4G
# 0 0 4
# 200
# 10937
# 1-95
# 0 0 3
# 1034
# G9514
# 397
# 19 902
# 2-52
# 0 0 3
# 397
# 1G360
# 2 0 7
# 0 0 3
# 517
# 22803
# 199
# G119
# 2-3G
# 0-OG
# 200
# 4G73
# 1-80
# 0 0 5
# TGES
# TGES
# TGES
# TGES
# TGES
# TGES
# TGES
# TGES
# TGES
# 3
# Th
# 312
# 914
# 70-2
# G30
# 12712
# 248
# 79G
# 4-40
# 0-43
# 234
# 849
# 4-09
# 0-45
# 1154
# 22 300
# 448
# 1G38
# 5-14
# 0-34
# 438
# 1362
# 4-28
# 0-27
# 566
# 27037
# 220
# 1951
# 507
# 0-21
# 221
# 1770
# 4-GO
# 0 1 9
# TIME
# TIME
# TIME
# TIME
# TIME
# TIME
# TIME
# TIME
# TIME
# i
# U
# 277
# 814
# 150
# 04:06:04
# 2599
# 04:39:00
# 391
# 2-26
# 0-43
# 04:43:43
# 5GG
# 3-27
# 0-50
# 09:48:02
# 3 087
# 11:02:54
# 896
# 3-64
# 0-38
# 11:10:48
# 787
# 3-20
# 0-33
# 03:14:4G
# 1498
# 04:05:22
# 302
# 3-62
# 0-33
# 04:09:49
# 301
# •
# 3 0 1
# 0-61
# 5
# Mo
# 140
# 420
# 2-GG
# S54
# 234
# 0-73
# 0-35
# 268
# 0-83
# 0-32
# 1188
# 313
# 0-70
# 0-26
# 271
# 0-61
# 0-20
# 182
# 77
# 112
# 116
# 12G
# 1-84
# 1-40
# 6
# Na
# 1368
# 3950
# 1-78
# 42389
# 14878
# 0-62
# 0 0 1
# 3 755
# 0-1G
# 001
# 33120
# 10871
# 0-58
# 0-01
# 2582
# 014
# 0 0 1
# 335
# 79
# 0-42
# 009
# 29
# 0 1 5
# 0 0 5
# 3.
# Analytical results
# 13 specific samples of different basalts and andesites were
# available to perform geochemical investigations in basaltic
# rock complexes. They had been selected from important
# geological points of view in Costa Rica (Fig. 1), covering
# the essential of tho magmatic differentiation and the geo-
# tectonically interesting volcanic areas.
# Tho distribution of tho samples ranged from picrites to
# andesites. Thus, among tho samples investigated, there were
# picrites of the ophiolito complex of Quepos (from tho last
# Cretaceous to Palaecene), alkaline basalts and also andesi-
# tic, basalts from tho volcanic eruptions, which, in part,
# took place in historical times.
# Tho usual REE, La, Ce, Nd, Sm, Eu, Tb, Yb, Lu and
# some other significant elements, of which Th, Hf, Sc, Fe,
# Ba, Rb, CsandTaare discussed here, have been investigat-
# ed. All tho samples used were obtained during field explora-
# tions and pulverized by means of achatc techniques.
# Tho samples having a weight of about 1.8 g together with
# the standard rocks BM and GM were irradiated with ther-
# mal neutrons (1013 ns-1 cm~2) at an exposure timo of about
# 180 minutes in the Research Reactor of tho Central Insti-
# tute for Nuclear Research (Academy of Sciences, GDR).
# Tho gamma-spectrometric measurements were performed
# by means of tho minicomputer after a cooling timo of 10
# and 30 days.
# Some of tho analytical results from tho 13 basaltic rocks
# are presented in Tab. 2. Tho lowest values of tho REE and
# thorium have been obtained for tho picrite (QU 1), which is
# also characterized by tho highest contents of Cr and Co.
# Wo can find rather concentrations of tho REE and Th
# for some andesites (samples G to 12 in Tab. 2), and mean
# values have been obtained for the alkaline basalts (samples
# 2 to 4 in Tab. 2).
# In order to evaluate the results with regard to tho regional
# spezialization of tho upper mantle or tho tectonic position,
# the mean trace element concentrations were calculated and
# 10
# Isotopenpraxis 21 (19S8) 1
#
# ----------------------------------------
# Document Metadata: {'source': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/10256018808623883.pdf', 'file_path': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/10256018808623883.pdf', 'page': 6, 'total_pages': 9, 'format': 'PDF 1.4', 'title': 'Computer-aided INAA Measurements and Geochemical Classification of Various Basaltic Rocks from Costa', 'author': '', 'subject': '', 'keywords': '', 'creator': 'ABBYY FineReader', 'producer': '', 'creationDate': "D:20080229114210+05'30'", 'modDate': "D:20080229114213+05'30'", 'trapped': ''}
# Document Content:
# Jusl et al.: Classification of Various Basaltic Rocks from Costa Rica
# Tali. 2. Trace clement and Fc values as results of INAA measurements for twelve of the investigated basalts and andesites from the Cost.i
# Rica region
# La
# Co
# Sm
# Ku
# Tb
# Yl>
# Lu
# Th
# U
# Co
# Cs
# Hf
# Sc
# Kb
# Fc
# Ta
# Ba
# Cr
# 1
# 4-1
# 150
# 1-0
# 0 0
# 0-2
# 0-5
# 0 1
# 0-9
# 0-4
# 105
# 0 0
# 2 0
# 14-2
# 47
# 10.5
# 0-3
# 37
# 800
# 2
# 130
# 201
# 3-2
# 1-2
# 0-4
# 1-3
# 0-2
# 1-4
# 0-5
# 37-0
# 1-0
# 1-5
# 30-5
# 31
# 9 1 '
# 0-3
# 208
# 80
# 3
# 190
# 330
# 5-3
# 2 0
# 0-3
# 1-4
# 0-22
# 1-8
# 1 1
# 44-3
# 0-5
# 2-5
# 37-5
# 32
# 10-8
# 0-2
# 307
# 32
# 4
# 140
# 2 3 0
# 3 1
# 1-2
# 0-2
# 0-6
# 018
# 2 0
# 1 0
# 3 5 0
# 1 1
# 1-4
# 25-4
# 30
# 9 1
# 0-2
# 309
# 22
# 5
# 7 1 .
# 170
# 2 1
# 0-9
# 0-3
# 0-9
# 0-21
# 0-5
# 0-2
# 34-2
# 0-8
# 1-6
# 24*2
# 44
# 8-9
# 0 3
# 350
# 11
# 6
# 4 0 0
# 1050
# 5-9
# 3-6
# 0-7
# 3 0
# 0-23
# 0-7
# 1-3
# 33-8
# 0-7
# 6-5
# 310
# 97
# 11G
# 0-0
# 1004
# 48
# 7
# 350
# 5G0
# CO
# 2 0
# 0-4
# 1-5
# 0-29
# 4-G
# 2 1
# 330
# 0 0
# 4 0
# 251
# 18
# 8-8
# 1 1
# 502
# CO
# 8
# 190
# 300
# 3-2
# 1 1
# 0-3
# 1-2
# 0-20
# 3-9
# 1-3
# 20-2
# 1-2
# 1-8
# 20-7
# 54
# G-7
# 0-4
# 813
# 10
# 9
# 2 3 0
# 3G0
# 3-6
# 1-4
# 0-4
# 0-9
# 0-21
# 5-5
# 1-8
# 17-0
# 1-1
# 2-7
# 129
# 70
# 5-5
# 0-2
# 975
# 21
# 10
# G7-0
# 1300
# 9-7
# 2-5
# 0-9
# 3 0
# 0-52
# 10-4
# 4G
# 140
# 1-7
# G-8
# 21-2
# 57
# G-9
# 1-7
# 1211
# 15
# 11
# 3S0
# 010
# 4-8
# 1-5
# 0-5
# 1-2
# 0-27
# 140
# 3-7
# 19.0
# 1-2
# 3-8
# 19-2
# 53
# 0-2
# 0-9
# 454
# 1G
# 12
# 3 5 0
# 000
# 5 0
# 1-9
# 1-0
# 1-9
# 0-24
# 5-2
# 1 0
# 3 1 0
# 0 0
# 4 1
# 29*2
# 87
# 7-9
# 0-7
# CGO
# 70
# (Fe in percent FCjO,, and all the other values in ppm)
# (1) QU 1
# Pieritie basalt from the ophiolite complex of Quepos (near the Pacific Ocean)
# (2) GGJ-X-1
# Alkaline basaltic rock from the Cerr Chopo region (Tilarau)
# (3) A 1
# Alkaline basalt (SiO, = 43-5), Puente La Garita
# (4) SP 15
# Basaltic rock
# (5) TAL 11
# Dacitic rock from the Cordillera de Talamanca (SiO, = G4%)
# (0) AT 1
# Andesite, near Athenas
# (7) B.K.
# Andesite
# (8) GGJ-IX 3
# Andesite, region of Las Juntas dc Abangares
# (9) Sil 1
# Andesite, northern part of San JIateo
# (10) COL 2
# Andesite, Tajo Colima, northern part of San Jos6 (SiO, = 54...01 %)
# (11) 5.
# Andesite
# (12) TUIl-3
# Andesite, volcanic layers of Turrialba (SiO, = 52%)
# The audesitie roek GG J-IX-2 having a low content of potassium from the Arenal volcanic complex and 55 % SiOs has been analyzed. We found
# only 12 ppm La, 0-8 ppm Th and 7-3% Fc,O,.
# Tab. 3. Main elements in two andesites and one basaltic rock from Costa Rica [%]
# SIO,
# A1,O,
# Fe,O,
# JIgO
# CaO
# Xa,0
# K , 0
# TiO,
# MnO
# P.O.
# (4)
# Sp 15
# (11)
# 5-
# (7)
# B.X.
# 48-53
# 57-84
# 50-91
# 19-93
# 17-52
# 10-51
# 10-58
# C-80
# 905
# G-04
# 3-98
# G-95
# 9-97
# 0-80
# 910
# 2-91
# 3-61
# 3-45
# 009
# 2-29
# 1-39
# 0-92
# 0-1G
# 1-4G
# 0-20
# 012
# 015
# 0-27
# 0-23
# 0-44
# basalts
# andesites
# andesites
# nro somo of tho data sots used for the correlation analyses.
# Another main element set is given for three of tho samples
# in Tab. 3.
# 4.
# Correlation analyses
# Tho investigated elements of various groups in basaltic
# rocks from somo geotectonic positions were available.
# Moro than 10 of the mean trace element values from all the
# groups obtained by Just [4, 5] are shown in Tab. 4, e.g.,
# ultrabasic rock complexes, peridotites, continental tholei-
# ites and picrites, basaltic rock from tho Romancho fracturo
# zone according to Just ct al. [7]. Devonian diabases and
# Tertiary basalts from the southern part of tho GDR together
# with tho basaltic rocks from tho Costa Rica region [8].
# As tho REE and also Th have been enriched during tho
# magmatie differentiation of a parent mantle-derived mag-
# ma, all the rocks arc tho data base and have been classified
# (from tho loft to the right in Tab. 4) in accordance with the
# increase of tho degree of magmatie differentiation. On the
# left wo can find primitive basalts and on tho right, highly
# differentiated continental rift basalts liko the Tertiary
# basalts (and also phonolites) from the Saxonian, in tho
# southern part of tho GDR. The concentrations increase,
# beginning with ultrabasites (1) followed by primitivo tholei-
# itic basalts found in tho northern part of tho GDR (2) and
# picrites (3) found in tho Rhono-Hercynian and Saxo-
# Thuringian zones, in tho southern part of tho GDR.
# Comparo tho intermediate concentrations for picrites
# with tho values of the samples QU 1 (sample 1 in Tab. 2).
# The position of somo differentiated oceanic basalts from
# tho Romancho fracture zone (4) and of tho Devonian dia-
# bases from tho Rheno-Hercynian zone in tho GDR (5)
# followed by tho mean values of the samples from Costa
# Rica (6) are tho next stage.
# Tho Saxonian Tertiary basalts [9], representing a typical
# continental intraplato volcanism, together with tho De-
# vonian keratophyric rocks are tho last groups followed by
# tho quartz keratophyres developed in tho Devonian, too.
# They have tho highest enrichments of the REE and thori-
# um.
# Thorium with an important set of elements is shown in
# Fig. 2. All tho calculated correlations of thorium with tho
# other investigated elements in each of tho cloven groups,
# discussed in this paper, aro shown in Tab. 5.
# All tho elements which are of importance for the classifi-
# cation, e.g., U, Ta, La and Rb show very good positive
# correlations in the data base of basaltic rocks. The plot of
# Isotopenpraxis 24 (19S8) 1
# 11
#
# ----------------------------------------
# Document Metadata: {'source': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/10256018808623883.pdf', 'file_path': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/10256018808623883.pdf', 'page': 7, 'total_pages': 9, 'format': 'PDF 1.4', 'title': 'Computer-aided INAA Measurements and Geochemical Classification of Various Basaltic Rocks from Costa', 'author': '', 'subject': '', 'keywords': '', 'creator': 'ABBYY FineReader', 'producer': '', 'creationDate': "D:20080229114210+05'30'", 'modDate': "D:20080229114213+05'30'", 'trapped': ''}
# Document Content:
# Just ot al.: Classification of Various Basaltic Rocks from Costa Rica
# Tab. 4. Mean values of the investigated trace elements and Fe in all the investigated groups with basaltic rocks from some regions and some
# geotcctonical positions [1]
# La
# Ce
# Xd
# Sm
# LUEE
# Th
# U
# Co
# Cs
# Hf
# Sc
# lib
# Fe
# Ta
# 1
# 1-9
# 5-6
# 6-7
# 1 0
# 12G
# 0-28
# 0-22
# 99-
# 4-3
# 0-9G
# 17-9
# 3-4
# 5-6
# 017
# 2
# 3-7
# 8-3
# 7G
# 2-8
# 22-4
# 0-35
# 007
# G9-
# 7-4
# 1-88
# 3 0 0
# 12-9
# 8-3
# 0-25
# 3
# 7-7
# 16-8
# 13-8
# 2-9
# 41-3
# 0-83
# 0-37
# 137-
# 9-2
# 2-45
# 160
# 131
# 10-4
# 0-53
# 4
# 170
# 10-5
# 15-6
# 3 1
# 54*5
# 1-45
# 0-41
# 49-
# 0-83
# 2-39
# 28-9
# 15-4
# 7-4
# 0-83
# 5
# 19-4
# 39-4
# 28-4
# 6 1
# 91-9
# 2-7
# 0-98
# 39-
# 3G
# 4-2
# 27-7
# 28-7
# 7 6
# 115
# G
# 25-4
# 40-4
# 230
# 4 0
# 1030
# 4-8
# 1-6
# 34-
# 0-85
# 3 1
# 240
# 47-8
# 8-4
# 0-51
# 7
# 37-3
# 85-7
# 53-9
# 9 1
# 1851
# 4 1
# 1-5
# 31-
# 5-8
# 7-9
# 22-8
# 62-G
# 7-2
# 3 0
# 8
# 41-3
# 75-4
# 520
# 7-7
# 179-9
# 6-5
# 1-77
# 52-
# 4 1
# 7-85
# 210
# G00
# 7-2
# 2-87
# 9 .
# 96-5
# 1504
# 106-1
# 11-4
# 364-5
# 10-6
# 3-4
# 49-
# 1-34
# G-74
# 22-5
# 1150
# 9-9
# 6-3
# 10
# 113-5
# 210-3
# 132-2
# 18-8
# 458-1
# 17-7
# 3-8
# 3-3
# 4-6
# 25-8
# 10-5
# 1330
# 5 1
# 7-75
# 11
# 90-2
# 177-3
# 104.1
# 171
# 388-8
# 21-8
# 5-4
# 6-6
# 2-7
# 23-1
# 3-6
# 164-0
# . 2-4
# 8-2
# (values are given in ppm, only Fe, in percent Fe,Oa)
# (1) ultrabasic rock complexes
# (2) olivine basalts, northern part of GDR
# (3) picrites
# (4) basaltic rocks, Romanche zone
# (5) diabases, GDR
# (6) basaltic and andesitic rocks of the Costa Rica region
# (7) spilites, GDR
# (8) mean values of all the basaltic rock samples
# (9) alkaline basaltic rocks, GDIt
# (10) keratophyrcs, GDR
# (11) quartz keratophyres, GDR
# Tab. 5. Correlations between thorium and the other investigated elements (Tab. 4)
# La
# Cc
# Xd
# Sm
# LREE
# U
# Co
# Cs
# Hf
# Sc
# Rb
# Fe
# Ta
# 1
# •73
# •73
# •72
# •71
# •72
# •83
# —80
# •75
# •69.
# •69
# •72
# •81
# •69
# 0
# - • 2 0
# —20
# -•50
# -•00
# —30
# •28
# •39
# -•GO
# -•80
# —80
# —40
# •36
# -•60
# 3
# •94
# •96
# •94
# •88
# •95
# •99
# — 90
# •88
# •96
# — 70
# •95
# —80
# •97
# i
# •90
# •93
# •89
# •90
# •93
# •82
# —40
# -•GO
# -•90
# - • 2 0
# -•GO
# —20
# •97
# 5
# •70
# •73
# •39
# •2G
# •39
# •79
# — 90
# -•30
# •34
# •90
# •84
# — 10
# -•10
# G
# •62
# •67
# •54
# •57
# •G2
# •88
# -•30
# -•40
# — 60
# •28
# •36
# •81
# •37
# 7
# •76
# •83
# •81
# •67
# •81
# •71
# •11
# •91
# •20
# -•40
# •89
# —10
# •31
# 8
# •86
# •8G
# •70
# •74
# •80
# •9G
# -•40
# •G8
# •72
# -•20
# •32
# — 50
# •8G
# 9
# •9S
# •98
# •94
# •97
# •98
# •87
# -•50
# —30
# •52
# — 70
# — 60
# •20
# •89
# 10
# •33
# •46
# •21
# - • 1
# •27
# •96
# •22
# •51
# — 10
# - • 4 0
# - • 4
# — 10
# •17
# all samples
# •92
# •94
# •92
# •95
# •94
# •98
# — 70
# -•30
# •94
# -•80
# •98
# -•GO
# •96
# number of samples: (1) 5 ultrabasic rocks: (2) 4 picrites: (3) 7 diabases: (4) 12 spilites: (5) 6 keratophyres: (6) 8 quartz keratophyres: (7) 12
# basalts, Romauche zone: (8) 13 basalts, Costa Rica: (9) 7 basalts, southern part of GDR: (10) 5 basalts, northern part of GDR
# Tab. 6. Correlation matrix with all the investigated elements in the data base of basaltic rocks
# La
# Co
# Nd
# Sm
# LREE
# Th
# U
# Co
# Cs
# III
# Sc
# Rb
# Fc
# Ta
# La
# 1-
# La
# Cc
# •99
# 1-
# Ce
# Xd
# •99
# •99
# 1-
# Xd
# Sm
# •95
# •99
# .97
# 1-
# Sm
# LREE
# •99
# •99
# •99
# •97
# 1-
# LREE
# Th
# •92
# •94
# •92
# •95
# •94
# 1-
# Th
# U
# •92
# •98
# •92
# •94
# •91
# •98
# 1-
# U
# Co
# — G8
# — 70
# — 67
# — 75
# — 70
# — 70
# — 70
# 1-
# Co
# Cs
# —35
# - • 2 5
# -•25
# —20
# - • 2 8
# — 30
# —36
# •5G
# 1-
# Cs
# Hf
# •G8
# •91
# •88
# •95
# •89
# •94
# •88
# — 69
# — 10
# 1-
# Hf
# Sc
# —Gl
# -•67
# —76
# — 67
# — 64
# — 76
# -•73
# •22
# •0
# -•76
# 1-
# Sc
# Rb
# •95
# •97
# •96
# •87
# •97
# •98
# •99
# -•72
# —32
# •89
# —69
# 1-
# Rb
# Fe
# -•40
# —48
# -.55
# -•55
# — 44
# —64
# -•57
# •57
# •22
# -•70
# •62
# —53
# 1-
# Fe
# Ta
# •97
# •98
# •97
# •97
# •98
# •96
# •90
# -•66
# -•24
# •90
# — 69
# •98
# -•52
# 1-
# Ta
# La
# Ce
# Xd
# Sm
# LREE
# Th
# U
# Co
# Cs
# Hf
# Sc
# Rb
# Fo
# Ta
# 12
# Isotopenpraxis 24 (1988) 1
#
# ----------------------------------------
# Document Metadata: {'source': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/10256018808623883.pdf', 'file_path': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/10256018808623883.pdf', 'page': 8, 'total_pages': 9, 'format': 'PDF 1.4', 'title': 'Computer-aided INAA Measurements and Geochemical Classification of Various Basaltic Rocks from Costa', 'author': '', 'subject': '', 'keywords': '', 'creator': 'ABBYY FineReader', 'producer': '', 'creationDate': "D:20080229114210+05'30'", 'modDate': "D:20080229114213+05'30'", 'trapped': ''}
# Document Content:
# Just et al.: Classification of Various Basaltic Rocks from Costa Rica
# ~ 70
# o
# « •
# ~ 30
# c
# *~ 20-
# t—
# z
# i io-
# 7
# 5
# I -
# 3 •
# 2
# 1
# 0.7 -
# 0.5
# 0.4
# 0.3
# 0.2-
# or
# » Granitic rock complexes
# o
# e
# ° °o o ° %
# „
# •
# •
# •
# ." p^* v"" ..•';..
# °
# °
# •• "
# °
# .
# . •
# • : : . » • ;
# *
# * , #
# • ••
# 1
# • Basaltic rocks
# 1
# 2
# 3 4 5 6 7
# 10
# 20 30 40 50
# 100
# 200 300
# 500
# 1000
# CONTENT La«Ce«Nd«Sm Iio'V.l
# Fig. 2. Thorium and the LUEE in granitic rocks and some basalts (results of INAA measurements)
# elements (Fig. 2) shows the relationship between thorium
# and the elements mentioned above. Furthermore, low
# values for ultrabasic rocks and primitive tholeiites of low
# differentiation and then the high concentrations for rela-
# tively highly differentiated continental volcanic rocks aro
# of interest. In order to elucidate the correlations, tho cor-
# relation matrix for all tho elements (e.g., Tab. C) is shown,
# the REE and Th have positive correlations with U, Hf, Ta
# and negative correlations with elements such as Co, Cs, Sc
# and Fe.
# Using the INAA measurements all the data sets aro ob-
# tained in a short measuring time, and wo have a good tool
# for the classification of basaltic rocks [10].
# The next stago of this work is the statistical feature
# extraction. An important set of elements is the ratio of Th
# to U. The samples from Costa Rica aro in the zone of tho
# basaltic rocks of tho Romancho type, and some dolerites
# aro from the Lusitanian stage (GDR) like some of the
# Tertiary basalts from the Saxonian.
# 5.
# Conclusions
# Tho results presented here are preliminary ones, because
# tho investigations are being continued at present. They are
# field investigations and also laboratory measurements
# carried out by means of the INAA method and X-ray
# fluorescence.
# The basaltic rocks from the Costa Rica region, which
# have been investigated, show a wide spectrum of chemical
# composition as is usual in zones of a subducing crust.
# The first results have shown that the computer-aided
# INAA measurements with a measuring time of about 30 min
# for one sample aro a powerful tool for rapidly classifying
# magmatic rock complexes (e.g., basaltic rocks).
# Tho correlation matrix shows that tho REE and thori-
# um have to be in positive correlations with TJ, Hf, Ta and
# also Rb in basaltic rocks (and in negative ones with tho
# elements Co, Sc, Cs and Fe) and this element set is very
# good for chemical classifications.
# Received September 24, 1980
# Accepted in revised form June 9, 1987
# References
# [1] F. A. Frey, TCev. Geophys. Space Phys. 17 (1979) 80.1
# [2] J. IF. Winchester, Hadioaetivation Analysis in Inorganic Geo-
# chemistry, in: Progress in Inorganic Chemistry, (F. A. Cotton, ed.).
# New York: Interscience I960, pp. 1—32
# [3] a. Just, C. Mickalk; IF. Kramer,
# G. ioos, Isotopenpraxis 23
# (1987) 157
# [4] Q. Just, Beitragc zur Klassifizierung granitoider Gesteine auf der
# Grundlage aktivierungsanalytischcr Bestimmungen scltener Ele-
# mente. Diss. A, Karl-Marx-Universitat Leipzig 1987
# [5] O. Just, Gerlands Ueitr. Geophysik (Leipzig) 94 (1983) 381
# [0] G. Just, IF. V. Fromm, 11. Zwanziger, Zur geoehemischen Cha-
# raktcrisierung von Granitoiden mittels rechncrgesteuerter IXAA-
# MeBtechnlk und multivariater Statistik. COMPAXA 85, 3. Tagung
# Computereinsatz in der Analytlk. Jena 1985
# [7] O. Just, W. Kramer, G. Loos, Z. Angew. Geol. 81 (1985) 18
# [8] IS. Gleisberg, S. Xiese, L. Pfeif/er, Isotopenpraxis 22 (19SG) 109
# [9] Ii. IF. Key, N. J. Ilubbard, Earth Planet. Sei. Lett. 8S (1978) 95
# [10] G. Just, IF. Kramer, G. Loos, Zur Amvendung der INAA bci der
# Untersuehung basaHischer Gesteine ozeaniscber und kontincntaler
# Ilerkunft. 3. Tagung Nukl. Analyseverfahren, Dresden 1983.
# Proceedings ZfK-524 (1984), S. 138-141
# Isotopenpraxia 21 (1988) 1
# 13
#
# ----------------------------------------
# Document Metadata: {'source': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/1104.4580.pdf', 'file_path': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/1104.4580.pdf', 'page': 0, 'total_pages': 52, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'creator': 'LaTeX with hyperref package', 'producer': 'dvips + GPL Ghostscript GIT PRERELEASE 9.22', 'creationDate': "D:20180528034025-04'00'", 'modDate': "D:20180528034025-04'00'", 'trapped': ''}
# Document Content:
# arXiv:1104.4580v3  [stat.ME]  14 Mar 2014
# QUANTILE REGRESSION WITH CENSORING AND ENDOGENEITY
# VICTOR CHERNOZHUKOV†
# IV´AN FERN´ANDEZ-VAL§
# AMANDA KOWALSKI‡
# Abstract. In this paper, we develop a new censored quantile instrumental variable (CQIV)
# estimator and describe its properties and computation.
# The CQIV estimator combines
# Powell (1986) censored quantile regression (CQR) to deal with censoring, with a control
# variable approach to incorporate endogenous regressors. The CQIV estimator is obtained in
# two stages that are nonadditive in the unobservables. The ﬁrst stage estimates a nonadditive
# model with inﬁnite dimensional parameters for the control variable, such as a quantile or
# distribution regression model. The second stage estimates a nonadditive censored quantile
# regression model for the response variable of interest, including the estimated control variable
# to deal with endogeneity. For computation, we extend the algorithm for CQR developed by
# Chernozhukov and Hong (2002) to incorporate the estimation of the control variable. We
# give generic regularity conditions for asymptotic normality of the CQIV estimator and for
# the validity of resampling methods to approximate its asymptotic distribution. We verify
# these conditions for quantile and distribution regression estimation of the control variable.
# Our analysis covers two-stage (uncensored) quantile regression with nonadditive ﬁrst stage
# as an important special case. We illustrate the computation and applicability of the CQIV
# estimator with a Monte-Carlo numerical example and an empirical application on estimation
# of Engel curves for alcohol.
# Date: May 28, 2018. We thank Denis Chetverikov and Sukjin Han for excellent comments and capable re-
# search assistance. We are grateful to Richard Blundell for providing us the data for the empirical application.
# We thank the editor Cheng Hsiao, two referees, and seminar participants at EIEF, Georgetown, Rochester,
# and Penn State for useful comments. We gratefully acknowledge research support from the NSF.
# † Department of Economics, MIT, 50 Memorial Drive, Cambridge, MA 02142, vchern@mit.edu.
# § Boston University, Department of Economics, 270 Bay State Road,Boston, MA 02215, ivanf@bu.edu.
# ‡ Department of Economics, Yale University, 37 Hillhouse Avenue, New Haven, CT 06520, and NBER,
# kowalski@nber.org.
# 1
#
# ----------------------------------------
# Document Metadata: {'source': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/1104.4580.pdf', 'file_path': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/1104.4580.pdf', 'page': 1, 'total_pages': 52, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'creator': 'LaTeX with hyperref package', 'producer': 'dvips + GPL Ghostscript GIT PRERELEASE 9.22', 'creationDate': "D:20180528034025-04'00'", 'modDate': "D:20180528034025-04'00'", 'trapped': ''}
# Document Content:
# 2
# 1. Introduction
# Censoring and endogeneity are common problems in data analysis. For example, income
# survey data are often censored due to top-coding and many economic variables such as
# hours worked, wages and expenditure shares are naturally bounded from below by zero.
# Endogeneity is also an ubiquitous phenomenon both in experimental studies due to partial
# noncompliance (Angrist, Imbens, and Rubin, 1996), and in observational studies due to si-
# multaneity (Koopmans and Hood, 1953), measurement error (Frish, 1934), sample selection
# (Heckman, 1979) or more generally to relevant omitted variables. Censoring and endogene-
# ity often come together in economic applications. For example, both of them arise in the
# estimation of Engel curves for alcohol – the relationship between the share of expenditure on
# alcohol and the household’s budget. For this commodity, a signiﬁcant fraction of households
# report zero expenditure, and economic theory suggests that the total expenditure and its
# composition are jointly determined in the consumption decision of the household. Either
# censoring or endogeneity lead to inconsistency of traditional mean and quantile regression
# estimators by inducing correlation between regressors and unobservables. We introduce a
# quantile regression estimator that deals with both problems and name this estimator the
# censored quantile instrumental variable (CQIV) estimator.
# Our procedure deals with censoring semiparametrically through the conditional quantile
# function following Powell (1986). This approach avoids the strong parametric assumptions
# of traditional Tobit estimators.
# The key ingredient here is the equivariance property of
# quantile functions to monotone transformations such as censoring. Powell’s censored quan-
# tile regression estimator, however, has proven to be diﬃcult to compute.
# We address this
# problem using the computationally attractive algorithm of Chernozhukov and Hong (2002).
# An additional advantage of focusing on the conditional quantile function is that we can cap-
# ture heterogeneous eﬀects across the distribution by computing CQIV at diﬀerent quantiles
# (Koenker, 2005). The traditional Tobit framework rules out this heterogeneity by imposing
# a location shift model.
# We deal with endogeneity using a control variable approach. The basic idea is to add
# a variable to the regression such that, once we condition on this variable, regressors and
# unobservables become independent. This so-called control variable is usually unobservable
# and needs to be estimated in a ﬁrst stage.
# Our main contribution here is to allow for
# semiparametric models with inﬁnite dimensional parameters and nonadditive unobservables,
# such as quantile regression and distribution regression, to model and estimate the ﬁrst stage
# and back out the control variable. This part of the analysis constitutes the main theoretical
# diﬃculty because the ﬁrst stage estimators do not live in spaces with nice entropic properties,
# unlike, for example, in Andrews (1994) or Newey (1994). To overcome this problem, we
#
# ----------------------------------------
# Document Metadata: {'source': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/1104.4580.pdf', 'file_path': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/1104.4580.pdf', 'page': 2, 'total_pages': 52, 'format': 'PDF 1.4', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'creator': 'LaTeX with hyperref package', 'producer': 'dvips + GPL Ghostscript GIT PRERELEASE 9.22', 'creationDate': "D:20180528034025-04'00'", 'modDate': "D:20180528034025-04'00'", 'trapped': ''}
# Document Content:
# 3
# develop a new technique to derive asymptotic theory for two-stage procedures with plugged-
# ...
# estimation when the estimation procedure is firststage(distribution), where
# string is either probit for probit estimation (the default) or logit for logit estima-
# tion.
# ldv2(string) determines the limited dependent variable model used in the ﬁrst step of
# the second-stage estimation, where string is either probit (the default) or logit.
# CQIV estimation
# corner calculates the (average) marginal quantile eﬀects for the censored dependent
# variable when the censoring is due to economic reasons, such as corner solutions.
# Under this option, the reported coeﬃcients are the average corner solution marginal
# eﬀects if the underlying function is linear in the endogenous variable; that is, the
# average of
# 1{Qy∗(u | d, w, v) > c}∂dQy∗(u | d, w, v) =
# 1{x(d, w, v)′β0(u) > c}∂d x(d, w, v)′β0(u)
# over all observations.
# If the underlying function is nonlinear in the endogenous
# variable, average marginal eﬀects must be calculated directly from the coeﬃcients
# without the corner option. For details of the related concepts, see section 2.1 of
# Chernozhukov, Fern´andez-Val, and Kowalski (2015). The relevant example can be
# found in section 3.5.
#
# ----------------------------------------
# Document Metadata: {'source': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/1536867X19893615.pdf', 'file_path': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/1536867X19893615.pdf', 'page': 9, 'total_pages': 14, 'format': 'PDF 1.6', 'title': 'Censored quantile instrumental-variable estimation with Stata', 'author': 'Victor Chernozhukov, Ivan Fernández-Val, Sukjin Han, and Amanda Kowalski', 'subject': 'The Stata Journal 2019.19:768-781', 'keywords': 'st0576,cqiv,quantile regression,censored data,endogeneity,instrumental variable,control function', 'creator': 'LaTeX with hyperref package', 'producer': 'dvips + GPL Ghostscript 9.25; modified using iText 4.2.0 by 1T3XT', 'creationDate': "D:20191122142001-06'00'", 'modDate': "D:20241108074833-08'00'", 'trapped': ''}
# Document Content:
# V. Chernozhukov, I. Fern´andez-Val, S. Han, and A. Kowalski
# 777
# drop1(#) sets the proportion of observations q0 with probabilities of censoring above
# the quantile index that are dropped in the ﬁrst step of the second stage (see remark 1
# above for details). The default is drop1(10).
# drop2(#) sets the proportion of observations q1 with estimates of the conditional quan-
# tile above (below for right-censoring) that are dropped in the second step of the
# second stage (see remark 2 above for details). The default is drop2(3).
# viewlog shows the intermediate estimation results. The default is no log.
# Inference
# confidence(string) speciﬁes the type of conﬁdence intervals. If string is speciﬁed as
# no, which is the default, then no conﬁdence intervals are calculated. If string is
# speciﬁed as boot or weightboot, then either nonparametric bootstrap or weighted
# bootstrap (respectively) t-percentile symmetric conﬁdence intervals are calculated.
# The weights of the weighted bootstrap are generated from the standard exponential
# distribution. Be aware that confidence(boot) and confidence(weightboot) can
# take a long time to execute.
# cluster(string) implements a cluster bootstrap procedure for clustered data when
# confidence(weightboot) is selected, with string specifying the variable that deﬁnes
# the group or cluster.
# bootreps(#) sets the number of repetitions of bootstrap or weighted bootstrap if
# confidence(boot) or confidence(weightboot) is also speciﬁed. The default is
# bootreps(100).
# setseed(#) sets the initial seed number in repetition of bootstrap or weighted boot-
# strap. The default is setseed(777).
# level(#) sets the conﬁdence level. The default is level(95).
# Robust check
# norobust suppresses the robustness diagnostic test results. There are no diagnostic test
# results to suppress when uncensored is used.
#
# ----------------------------------------
# Document Metadata: {'source': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/1536867X19893615.pdf', 'file_path': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/1536867X19893615.pdf', 'page': 10, 'total_pages': 14, 'format': 'PDF 1.6', 'title': 'Censored quantile instrumental-variable estimation with Stata', 'author': 'Victor Chernozhukov, Ivan Fernández-Val, Sukjin Han, and Amanda Kowalski', 'subject': 'The Stata Journal 2019.19:768-781', 'keywords': 'st0576,cqiv,quantile regression,censored data,endogeneity,instrumental variable,control function', 'creator': 'LaTeX with hyperref package', 'producer': 'dvips + GPL Ghostscript 9.25; modified using iText 4.2.0 by 1T3XT', 'creationDate': "D:20191122142001-06'00'", 'modDate': "D:20241108074833-08'00'", 'trapped': ''}
# Document Content:
# 778
# CQIV
# 3.4
# Stored results
# cqiv stores the following results in e():
# Scalars
# e(obs)
# number of observations
# e(censorpt)
# ﬁxed censoring point
# e(drop1)
# q0
# e(drop2)
# q1
# e(bootreps)
# number of bootstrap or weighted bootstrap repetitions
# e(level)
# signiﬁcance level of conﬁdence interval
# Macros
# e(command)
# cqiv
# e(depvar)
# name of dependent variable
# e(regression)
# name of the implemented regression: either cqiv, qiv, or cqr
# e(endogvar)
# name of endogenous regressor
# e(instrument)
# names of instrumental variables
# e(censorvar)
# name of censoring variable
# e(regressors)
# names of the regressors
# e(firststage)
# type of ﬁrst-stage estimation
# e(confidence)
# type of conﬁdence intervals
# Matrices
# e(results)
# matrix containing the estimated coeﬃcients, means, standard errors,
# and lower and upper bounds of conﬁdence intervals
# e(quantiles)
# row vector containing the quantiles at which CQIV has been estimated
# e(robustcheck)
# matrix containing the results for the robustness diagnostic test results;
# see table 1 below
# In the following table, we present the CQIV robustness diagnostic tests suggested
# in Chernozhukov, Fern´andez-Val, and Kowalski (2015) for the CQIV estimator with an
# OLS estimate of the control variable. See section 2.1 of that article for the deﬁnitions
# of k0, ς1, J0, and J1. In our estimates, we used a probit model in the ﬁrst step, and
# we set q0 = 10 and q1 = 3. In practice, we do not necessarily recommend reporting the
# diagnostics in table 1, but we do recommend examining them.
#
# ----------------------------------------
# Document Metadata: {'source': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/1536867X19893615.pdf', 'file_path': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/1536867X19893615.pdf', 'page': 11, 'total_pages': 14, 'format': 'PDF 1.6', 'title': 'Censored quantile instrumental-variable estimation with Stata', 'author': 'Victor Chernozhukov, Ivan Fernández-Val, Sukjin Han, and Amanda Kowalski', 'subject': 'The Stata Journal 2019.19:768-781', 'keywords': 'st0576,cqiv,quantile regression,censored data,endogeneity,instrumental variable,control function', 'creator': 'LaTeX with hyperref package', 'producer': 'dvips + GPL Ghostscript 9.25; modified using iText 4.2.0 by 1T3XT', 'creationDate': "D:20191122142001-06'00'", 'modDate': "D:20241108074833-08'00'", 'trapped': ''}
# Document Content:
# V. Chernozhukov, I. Fern´andez-Val, S. Han, and A. Kowalski
# 779
# Table 1.
# CQIV robustness diagnostic test results for CQIV with OLS estimate of the
# control variable—homoskedastic design
# CQIV-OLS Step 1
# k0
# Percent J0
# Quantile
# Median
# Min
# Max
# Median
# Min
# Max
# 0.05
# 0.04
# 0.04
# 0.05
# 47.20
# 43.30
# 50.30
# 0.1
# 0.09
# 0.06
# 0.10
# 49.10
# 46.00
# 51.30
# 0.25
# 0.20
# 0.15
# 0.24
# 52.20
# 50.50
# 53.70
# 0.5
# 0.36
# 0.26
# 0.46
# 55.80
# 54.80
# 56.80
# 0.75
# 0.43
# 0.29
# 0.58
# 59.40
# 57.70
# 61.10
# 0.9
# 0.37
# 0.22
# 0.58
# 62.40
# 60.30
# 65.10
# 0.95
# 0.30
# 0.18
# 0.54
# 64.20
# 61.40
# 67.50
# CQIV-OLS Step 2
# 1
# Percent J1
# Percent Predicted Above C
# Quantile
# Median
# Min
# Max
# Median
# Min
# Max
# Median
# Min
# Max
# 0.05
# 1.7
# 1.45
# 2.01
# 50.7
# 46.7
# 54.9
# 52.3
# 48.2
# 56.7
# 0.1
# 1.71
# 1.44
# 1.96
# 52.8
# 49.5
# 55.5
# 54.5
# 51.1
# 57.3
# 0.25
# 1.71
# 1.46
# 1.98
# 56.3
# 53.6
# 58.7
# 58.1
# 55.3
# 60.6
# 0.5
# 1.72
# 1.44
# 2.02
# 60.1
# 57.6
# 63.4
# 62
# 59.4
# 65.4
# 0.75
# 1.73
# 1.47
# 1.99
# 64
# 61.2
# 66.8
# 66
# 63.1
# 68.9
# 0.9
# 1.75
# 1.44
# 2.01
# 67.4
# 64.6
# 70.6
# 69.5
# 66.6
# 72.8
# 0.95
# 1.76
# 1.49
# 2.02
# 69.3
# 65.6
# 72.8
# 71.5
# 67.7
# 75.1
# Percent J0 in J1
# Count in J1 not in J0
# Quantile
# Median
# Min
# Max
# Median
# Min
# Max
# Median
# Min
# Max
# 0.05
# 1.6
# 1.33
# 1.85
# 100
# 97.7
# 100
# 36
# 0
# 81
# 0.1
# 1.6
# 1.33
# 1.85
# 100
# 99
# 100
# 37
# 7
# 74
# 0.25
# 1.6
# 1.33
# 1.85
# 100
# 99.6
# 100
# 40
# 15
# 68
# 0.5
# 1.6
# 1.33
# 1.85
# 100
# 99.6
# 100
# 43
# 23
# 78
# 0.75
# 1.6
# 1.33
# 1.85
# 100
# 99.7
# 100
# 47
# 17
# 74
# 0.9
# 1.6
# 1.33
# 1.85
# 100
# 99.7
# 100
# 50
# 15
# 88
# 0.95
# 1.6
# 1.33
# 1.85
# 100
# 99.1
# 100
# 51
# 16
# 97
# Comparison of Objective Functions
# Objective Step 3
# 0bjective Step 2
# Objective Step 3<0bjective Step 2
# Quantile
# Median
# Min
# Max
# Median
# Min
# Max
# Median
# Mean
# 0.05
# 5058
# 4458
# 5674
# 5054
# 4400
# 5753
# 0
# 0.44
# 0.1
# 8939
# 7925
# 9946
# 8927
# 7888
# 10049
# 0
# 0.47
# 0.25
# 17292
# 15100
# 19839
# 17271
# 14741
# 20052
# 0
# 0.44
# 0.5
# 22859
# 18692
# 27022
# 22837
# 18306
# 27091
# 0
# 0.45
# 0.75
# 16073
# 9603
# 22872
# 15895
# 8737
# 22866
# 0
# 0.42
# 0.9
# -1016
# -9624
# 7150
# -1047
# -10834
# 9265
# 0
# 0.45
# 0.95
# -13815
# -24602
# -2884
# -14034
# -27816
# -1919
# 0
# 0.44
# N=1,000, Replications=1,000
# In the top section of the table, we present diagnostics computed after CQIV step 1. In
# the second section, we present robustness test diagnostics computed after CQIV step 2.
# In the last section, we report the value of the Powell objective function obtained after
# CQIV step 2 and CQIV step 3. See Chernozhukov, Fern´andez-Val, and Kowalski (2015)
# for more discussion.
# 3.5
# Examples
# We illustrate how to use cqiv with some examples. For the dataset, we use a household
# expenditure dataset for alcohol consumption drawn from the British Family Expenditure
# Survey; see Blundell, Chen, and Kristensen (2007) and Chernozhukov, Fern´andez-Val,
#
# ----------------------------------------
# Document Metadata: {'source': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/1536867X19893615.pdf', 'file_path': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/1536867X19893615.pdf', 'page': 12, 'total_pages': 14, 'format': 'PDF 1.6', 'title': 'Censored quantile instrumental-variable estimation with Stata', 'author': 'Victor Chernozhukov, Ivan Fernández-Val, Sukjin Han, and Amanda Kowalski', 'subject': 'The Stata Journal 2019.19:768-781', 'keywords': 'st0576,cqiv,quantile regression,censored data,endogeneity,instrumental variable,control function', 'creator': 'LaTeX with hyperref package', 'producer': 'dvips + GPL Ghostscript 9.25; modified using iText 4.2.0 by 1T3XT', 'creationDate': "D:20191122142001-06'00'", 'modDate': "D:20241108074833-08'00'", 'trapped': ''}
# Document Content:
# 780
# CQIV
# and Kowalski (2015) for a detailed description of the data. We are interested in learning
# how the share of total expenditure on alcohol (alcohol) is aﬀected by (the logarithm
# of) total expenditure (logexp), controlling for the number of children (nkids). For the
# endogenous expenditure, we use disposable income, that is, (the logarithm of) gross
# earnings of the head of the household (logwages), as an excluded instrument.
# . use alcoholengel
# Given this dataset, we can generate part of the empirical results of Chernozhukov,
# Fern´andez-Val, and Kowalski (2015):
# . cqiv alcohol logexp2 nkids (logexp = logwages nkids), quantiles(25 50 75)
# (output omitted )
# Here logexp2 is the squared (logarithm of) total expenditure.
# Using the cqiv
# command, the QIV estimation can be implemented with the uncensored option:
# . cqiv alcohol logexp2 nkids (logexp = logwages nkids), uncensored
# (output omitted )
# And the CQR estimation can be implemented with the exogenous option:
# . cqiv alcohol logexp logexp2 nkids, exogenous
# (output omitted )
# Here are other examples of the CQIV estimation with diﬀerent speciﬁcations and
# options. Outputs are all omitted.
# . cqiv alcohol logexp2 (logexp = logwages), quantiles(20 25 70(5)90)
# > firststage(ols)
# . cqiv alcohol (logexp = logwages), firststage(distribution) ldv1(logit)
# . cqiv alcohol logexp2 nkids (logexp = logwages), firstvar(nkids)
# . cqiv alcohol logexp2 nkids (logexp = logwages nkids), confidence(weightboot)
# > bootreps(10)
# . cqiv alcohol nkids (logexp = logwages nkids), corner
# In order of appearance, the commands conduct the estimation using OLS in the ﬁrst
# stage; the estimation using distribution regression with logistic distribution; the estima-
# tion where nkids is the only variable other than the instrument that is included in the
# ﬁrst-stage estimation; the estimation with two instruments and calculating the conﬁ-
# dence interval using the weighted bootstrap; and the estimation calculating the marginal
# eﬀects when censoring is due to corner solutions. In this last example, logexp2 cannot
# be included in the ﬁrst-stage regression when distribution regression is implemented,
# because logexp2 is a monotone transformation of logexp. Thus, the distribution esti-
# mation yields a perfect ﬁt.
# 4
# Acknowledgments
# We thank Simon J¨ager, Blaise Melly, and Sanna Nivakoski for helpful comments.
#
# ----------------------------------------
# Document Metadata: {'source': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/1536867X19893615.pdf', 'file_path': '/nfs/turbo/si-acastel/expert_field_project/full_pdfs_by_author/aekowals/1536867X19893615.pdf', 'page': 13, 'total_pages': 14, 'format': 'PDF 1.6', 'title': 'Censored quantile instrumental-variable estimation with Stata', 'author': 'Victor Chernozhukov, Ivan Fernández-Val, Sukjin Han, and Amanda Kowalski', 'subject': 'The Stata Journal 2019.19:768-781', 'keywords': 'st0576,cqiv,quantile regression,censored data,endogeneity,instrumental variable,control function', 'creator': 'LaTeX with hyperref package', 'producer': 'dvips + GPL Ghostscript 9.25; modified using iText 4.2.0 by 1T3XT', 'creationDate': "D:20191122142001-06'00'", 'modDate': "D:20241108074833-08'00'", 'trapped': ''}
# Document Content:
# V. Chernozhukov, I. Fern´andez-Val, S. Han, and A. Kowalski
# 781
# 5
# Programs and supplemental materials
# To install a snapshot of the corresponding software ﬁles as they existed at the time of
# publication of this article, type
# . net sj 19-4
# . net install st0576
# (to install program ﬁles, if available)
# . net get st0576
# (to install ancillary ﬁles, if available)
# 6
# References
# Blundell, R., X. Chen, and D. Kristensen. 2007. Semi-nonparametric IV estimation of
# shape-invariant Engel curves. Econometrica 75: 1613–1669.
# Chernozhukov, V., I. Fern´andez-Val, and A. Galichon. 2010. Quantile and probability
# curves without crossing. Econometrica 78: 1093–1125.
# Chernozhukov, V., I. Fern´andez-Val, and A. E. Kowalski. 2015. Quantile regression with
# censoring and endogeneity. Journal of Econometrics 186: 201–221.
# Chernozhukov, V., I. Fern´andez-Val, and B. Melly. 2013. Inference on counterfactual
# distributions. Econometrica 81: 2205–2268.
# Chernozhukov, V., and H. Hong. 2002. Three-step censored quantile regression and
# extramarital aﬀairs. Journal of the American Statistical Association 97: 872–882.
# Deaton, A. S., and J. Muellbauer. 1980. Economics and Consumer Behavior. Cambridge:
# Cambridge University Press.
# Foresi, S., and F. Peracchi. 1995. The conditional distribution of excess returns: An
# empirical analysis. Journal of the American Statistical Association 90: 451–466.
# Gorman, W. M. 1959. Separable utility and aggregation. Econometrica 27: 469–481.
# Koenker, R., and G. Bassett, Jr. 1978. Regression quantiles. Econometrica 46: 33–50.
# Kowalski, A. 2016. Censored quantile instrumental variable estimates of the price elas-
# ticity of expenditure on medical care. Journal of Business & Economic Statistics 34:
# 107–117.
# Powell, J. L. 1986. Censored regression quantiles. Journal of Econometrics 32: 143–155.
# About the authors
# Victor Chernozhukov is Ford International Professor at the Department of Economics and the
# Center for Statistics and Data Science at MIT.
# Ivan Fern´andez-Val is a Professor in Economics at Boston University.
# Sukjin Han is an Assistant Professor in Economics at University of Texas at Austin.
# Amanda Kowalski is Gail Wilensky Professor of Applied Economics and Public Policy at Uni-
# versity of Michigan.
#
# ----------------------------------------

# %%
# Initialize a text splitter with specified chunk size and overlap
text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    chunk_size=250, chunk_overlap=0
)
# Split the documents into chunks
doc_splits = text_splitter.split_documents(all_documents)
print(doc_splits)
# Out:
# []

# %%
from langchain_community.vectorstores import SKLearnVectorStore
from langchain_huggingface.embeddings import HuggingFaceEmbeddings


#TODO: not a priority but try a local embedding again
vectorstore = SKLearnVectorStore.from_documents(
    documents=doc_splits,
    embedding=HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
)
retriever = vectorstore.as_retriever(k=4)

# %%
import socket, os, subprocess

# Get random port
s = socket.socket()
s.bind(('', 0))
port = s.getsockname()[1]
s.close()

# Set environment variables
os.environ['OLPORT'] = str(port)
os.environ['OLLAMA_HOST'] = f'127.0.0.1:{port}'
os.environ['OLLAMA_BASE_URL'] = f'http://localhost:{port}'

ollama_path = os.path.expanduser('~/ollama/bin/ollama')
subprocess.Popen([ollama_path, 'serve'], 
                stdout=open(f'ollama_{port}.log', 'w'),
                stderr=open(f'ollama_{port}.err', 'w'))

print(f"Ollama started on port {port}")
# Out:
# Ollama started on port 48019

# %%
from langchain.schema import Document
from langchain_community.tools.tavily_search import TavilySearchResults

web_search_tool = TavilySearchResults()

# %%
from langchain_ollama import ChatOllama 
from langchain.prompts import PromptTemplate 
from langchain_core.output_parsers import StrOutputParser

ollama_base_url = f"http://localhost:{port}"
prompt = PromptTemplate(
    template="""You are an assistant for question-answering tasks about researchers at the univeristy of michigan.
    Use the following documents to answer the question.
    If you don't know the answer, just say that you don't know.
    Use three sentences maximum and keep the answer concise:
    Question: {question}
    Documents: {documents}
    Answer:
    """,
    input_variables=["question", "documents"],
)
llm = ChatOllama(
model="llama3.1", temperature=0, base_url=ollama_base_url
)
rag_chain = prompt | llm | StrOutputParser()

# %%
from langchain_core.prompts import ChatPromptTemplate 
from langchain_core.output_parsers import JsonOutputParser

# JSON
llm = ChatOllama(model="llama3.1", format="json" , temperature=0,  base_url=ollama_base_url)

prompt = PromptTemplate(
template="""You are a grader assessing relevance of a retrieved document 
            to a user question. \nHere.
            is the retrieved document: \n\n {document} \n\n
            Here is the user question: {question} \n
            If the document contains keywords related to the user question grade it as relevant.  
            It does not need to be a stringent test. 
            The goal is to filter out erroneous retrievals. \n
            Give a binary score 'yes' or 'no' score to indicate whether the document is relevant to the question. \n 
            Provide the binary score as a JSON with a single key 'score' and no premable or explanation.""",
            input_variables=["question", "document"],
)
retrieval_grader = prompt | llm | JsonOutputParser ()

# %%
from typing_extensions import TypedDict, List 
from IPython.display import Image, display 
from langgraph.graph import START, END, StateGraph

class GraphState(TypedDict):
    """AssertionError
            Represents the state of our graph.
            Attributes:
            question: question generation: LL generation search: whether to add search documents: list of documents
            question: str generation: str search: str
            documents: List (str]
    """
    question: str
    generation: str
    search: str
    documents: List[str]
    steps: List[str]

def retrieve(state):
    """
    Retrieve documents
    Args:
    state (dict): The current graph state
    Returns:
    state (dict): New key added to state, documents, that contains retrieved
    """
    question = state["question"]
    documents = retriever.invoke(question)
    steps = state["steps"]
    steps.append("retrieve_documents")
    return {"documents": documents, "question": question, "steps": steps}

def generate(state):
    """Generate answer
    Args:
    state (dict): The current graph state
    Returns:
    state (dict): New key added to state, generation, that contains LUM generation"""

    question = state["question"]
    documents = state["documents"]
    generation = rag_chain.invoke({"documents": documents, "question": question})
    steps = state["steps"]
    steps.append ("generate_answer")
    return {
        "documents": documents,
        "question": question,
        "generation": generation,
        "steps": steps,
    }

def grade_documents(state):
    """
    Args:
    state (dict): The current graph state
    Returns:
    state (dict): Updates documents key with only filtered relevant documents
    """
    question = state["question" ]
    documents = state["documents"]
    steps = state["steps"]
    steps.append("grade_document_retrieval")
    filtered_docs = []
    search = "No"
    for d in documents:
        score = retrieval_grader.invoke(
            {"question": question, "document": d.page_content}
        )
        grade = score["score"]
        if grade == "yes":
            filtered_docs.append(d)
        else:
            search = "Yes"  
            continue
    return{
        "documents": filtered_docs,
        "question": question,
        "search": search,
        "steps": steps,
    }

def web_search(state):
    """
    Web search based on the re-phrased question.
    Args:
    state (dict): The current graph state
    Returns:
    state (dict): Updates documents key with appended web results
    """
    question = state["question"]
    documents = state.get("documents", [])
    steps = state["steps"]
    steps.append("web_search")
    web_results = web_search_tool.invoke({"query": question})
    documents.extend(
        [
            Document(page_content=d["content"], metadata={"url": d["url"]}) 
            for d in web_results
        ]
    )
    return {"documents": documents, "question": question, "steps": steps}

def decide_to_generate(state):
    """Determines whether to generate an answer, or re-generate a question.
    Args:
    state (dict): The current graph state
    Returns:
    str: Binary decision for next node to call
    """
    search = state["search"]
    if search == "Yes":
        return "search" 
    else:
        return "generate"

def classify_question(state):
    """Classify if question requires doc summary vs specific answer"""
    question = state["question"]
    documents = state["documents"]  # Need documents from retrieve step
    classifier = pipeline("text-classification", model="cnmoro/bert-tiny-question-classifier")
    result = classifier(question)
    question_type = result[0]['label']
    steps = state["steps"]
    steps.append("classify_question")
    return {
        "question": question,
        "question_type": question_type,
        "documents": documents,  # Pass documents through
        "steps": steps
    }

def decide_path(state):
    """Route to summary or regular RAG flow"""
    return "summarize" if state["question_type"] == "LABEL_1" else "grade_documents" 

def generate_summary(state):
    """Summarize documents"""
    documents = state["documents"]
    steps = state["steps"]
    steps.append("generate_summary")

    # Combine doc contents
    combined_text = "\n".join([doc.page_content for doc in documents])
    
    prompt = ChatPromptTemplate.from_template("""
    Summarize the following text:
    {text}
    """)

    summary_chain = prompt | ChatOllama(model="llama3.1", base_url=ollama_base_url)
    summary = summary_chain.invoke({"text": combined_text})

    return {
        "documents": documents,
        "question": state["question"], 
        "generation": summary.content,
        "steps": steps
    }

# Graph
workflow = StateGraph(GraphState)
# Define the nodes
workflow.add_node("retrieve", retrieve) 
workflow.add_node("grade_documents", grade_documents) # grade documents 
workflow.add_node("generate", generate) # generatae 
workflow.add_node("web_search", web_search) # web search
# Build graph
workflow.set_entry_point("retrieve")
workflow.add_edge("retrieve", "grade_documents") 
workflow.add_conditional_edges(
    "grade_documents", 
    decide_to_generate,
    {
        "search": "web_search",
        "generate": "generate",
    },
)
workflow.add_edge("web_search", "generate")
workflow.add_edge("generate", END)
custom_graph = workflow.compile()

display(Image(custom_graph.get_graph(xray=True).draw_mermaid_png()))

# %%
# import uuid

def predict_custom_agent_answer(example: dict):
    # config = {"configurable": {"thread_id": str(uuid.uuid4())}}
    state_dict = custom_graph.invoke({"question": example["input"], "steps": []})
    return {"response": state_dict["generation"], "steps": state_dict["steps"]} 

example = {"input": "what does using ols do in the first stage"}
response = predict_custom_agent_answer(example)
response
# Out:
# {'response': 'Based on the provided documents, it appears that the question is asking about the effect of specifying "OLS" in a two-stage least squares (2SLS) estimation.\n\nIn the first stage, reduced-form equations are estimated. The specification of "OLS" in this context refers to the fact that ordinary least squares (OLS) regression is used to estimate the reduced-form equations.\n\nHowever, the question seems to be asking about the effect of specifying "OLS" in a different context, which is not explicitly mentioned in the provided documents.\n\nIf I had to make an educated guess based on the general knowledge of econometrics and 2SLS estimation, I would say that specifying "OLS" in this context might refer to the fact that OLS regression is used to estimate the structural equations using the first-stage predictions as instruments. In other words, it\'s about how the second stage of the 2SLS estimation is performed.\n\nBut without more specific information or context, it\'s difficult to provide a definitive answer.\n\nSo, my final answer would be:\n\n"I\'m not sure what you\'re asking, but I think it might have something to do with the specification of OLS in the second stage of a two-stage least squares (2SLS) estimation. If that\'s correct, then the effect of specifying \'OLS\' is that ordinary least squares regression is used to estimate the structural equations using the first-stage predictions as instruments."',
#  'steps': ['retrieve_documents',
#   'grade_document_retrieval',
#   'web_search',
#   'generate_answer']}

# %%
# import uuid

def predict_custom_agent_answer(example: dict):
    # config = {"configurable": {"thread_id": str(uuid.uuid4())}}
    state_dict = custom_graph.invoke({"question": example["input"], "steps": []})
    return {"response": state_dict["generation"], "steps": state_dict["steps"]} 

example = {"input": "where can I contact amanda kowalski"}
response = predict_custom_agent_answer(example)
response
# Out:
# {'response': "You can contact Amanda Kowalski through the University of Michigan's expert profile, which is available at https://experts.umich.edu/5421-amanda-kowalski. This page provides a link to contact her. Additionally, you can also try contacting her department, the Department of Economics at the University of Michigan.",
#  'steps': ['retrieve_documents',
#   'grade_document_retrieval',
#   'web_search',
#   'generate_answer']}

# %% [markdown]
# ## example with regular prompt

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama import ChatOllama
from langchain_core.runnables import RunnablePassthrough

ollama_base_url = f"http://localhost:{port}"

prompt = ChatPromptTemplate.from_template("""
Answer the question based only on the following context. If you cannot answer the question based on the context, say "I cannot answer this based on the provided context."

Context: {context}
Question: {question}

Answer: """)

# 6. Create chain
chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt
    | ChatOllama(model="llama3.1", base_url=ollama_base_url)
)

# 7. Interactive question-answering loop
print("RAG System Ready! Ask questions about your documents (type 'quit' to exit)")
print("-" * 50)

while True:
    question = input("\nYour question: ")
    if question.lower() in ['quit', 'exit', 'q']:
        print("Goodbye!")
        break
    
    try:
        response = chain.invoke(question)
        print("\nAnswer:", response)
        print("-" * 40)  # Separator line
    except Exception as e:
        print(f"\nAn error occurred: {str(e)}")
# Out:
# RAG System Ready! Ask questions about your documents (type 'quit' to exit)
# --------------------------------------------------
#
# Answer: content='I cannot summarize these documents as I do not have the context to do so. However, I can suggest a possible approach to summarizing them.\n\nTo summarize the documents, I would first need to understand the content of each document and identify any common themes or keywords. Based on the provided metadata, it appears that the documents are related to computer-aided analysis of basaltic rocks from Costa Rica using INAA (Instrumental Neutron Activation Analysis) measurements. However, without access to the actual content of the documents, I cannot provide a summary.\n\nIf you would like me to try and summarize the documents based on the provided metadata alone, please let me know.' additional_kwargs={} response_metadata={'model': 'llama3.1', 'created_at': '2024-12-07T22:20:34.889265556Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 6608745171, 'load_duration': 2709051469, 'prompt_eval_count': 1509, 'prompt_eval_duration': 435000000, 'eval_count': 135, 'eval_duration': 3463000000} id='run-529e03bf-a962-4944-9a44-613cd6b625b2-0' usage_metadata={'input_tokens': 1509, 'output_tokens': 135, 'total_tokens': 1644}
# ----------------------------------------
#
# Answer: content='I cannot answer this based on the provided context.' additional_kwargs={} response_metadata={'model': 'llama3.1', 'created_at': '2024-12-07T22:23:03.932750327Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 822770458, 'load_duration': 76790718, 'prompt_eval_count': 1687, 'prompt_eval_duration': 456000000, 'eval_count': 11, 'eval_duration': 288000000} id='run-f3473c51-c870-4346-b8a8-8289883270e8-0' usage_metadata={'input_tokens': 1687, 'output_tokens': 11, 'total_tokens': 1698}
# ----------------------------------------
#
# Answer: content='I cannot answer this based on the provided context.' additional_kwargs={} response_metadata={'model': 'llama3.1', 'created_at': '2024-12-07T22:23:06.371926597Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 329207812, 'load_duration': 26236024, 'prompt_eval_count': 1687, 'prompt_eval_duration': 19000000, 'eval_count': 11, 'eval_duration': 282000000} id='run-0e16ada9-6718-4551-b625-729fa48fe053-0' usage_metadata={'input_tokens': 1687, 'output_tokens': 11, 'total_tokens': 1698}
# ----------------------------------------
#
# Answer: content='I cannot answer this based on the provided context.' additional_kwargs={} response_metadata={'model': 'llama3.1', 'created_at': '2024-12-07T22:23:07.619096697Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 393297996, 'load_duration': 21085259, 'prompt_eval_count': 1687, 'prompt_eval_duration': 22000000, 'eval_count': 11, 'eval_duration': 348000000} id='run-ca85f119-093c-43d1-a613-aacf51a99345-0' usage_metadata={'input_tokens': 1687, 'output_tokens': 11, 'total_tokens': 1698}
# ----------------------------------------
#
# Answer: content='I cannot answer this based on the provided context.' additional_kwargs={} response_metadata={'model': 'llama3.1', 'created_at': '2024-12-07T22:23:08.6826058Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 309918780, 'load_duration': 22855979, 'prompt_eval_count': 1687, 'prompt_eval_duration': 19000000, 'eval_count': 11, 'eval_duration': 266000000} id='run-3600c1e1-8daf-4fbf-846b-209a40e22fec-0' usage_metadata={'input_tokens': 1687, 'output_tokens': 11, 'total_tokens': 1698}
# ----------------------------------------
#
# Answer: content='I cannot answer this based on the provided context.' additional_kwargs={} response_metadata={'model': 'llama3.1', 'created_at': '2024-12-07T22:23:10.604321401Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 306623240, 'load_duration': 19612311, 'prompt_eval_count': 1687, 'prompt_eval_duration': 20000000, 'eval_count': 11, 'eval_duration': 266000000} id='run-0517d53f-ec82-4694-b242-48838c437c14-0' usage_metadata={'input_tokens': 1687, 'output_tokens': 11, 'total_tokens': 1698}
# ----------------------------------------
#
# Answer: content='I cannot answer this based on the provided context.' additional_kwargs={} response_metadata={'model': 'llama3.1', 'created_at': '2024-12-07T22:23:12.097299421Z', 'message': {'role': 'assistant', 'content': ''}, 'done_reason': 'stop', 'done': True, 'total_duration': 303995337, 'load_duration': 19537675, 'prompt_eval_count': 1687, 'prompt_eval_duration': 20000000, 'eval_count': 11, 'eval_duration': 263000000} id='run-9fd80bc9-9ca2-448a-831c-c835c8576fd5-0' usage_metadata={'input_tokens': 1687, 'output_tokens': 11, 'total_tokens': 1698}
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 27
#      24 print("-" * 50)
#      26 while True:
# ---> 27     question = input("\nYour question: ")
#      28     if question.lower() in ['quit', 'exit', 'q']:
#      29         print("Goodbye!")
#
# File ~/.conda/envs/test_env/lib/python3.11/site-packages/ipykernel/kernelbase.py:1262, in Kernel.raw_input(self, prompt)
#    1260     msg = "raw_input was called, but this frontend does not support input requests."
#    1261     raise StdinNotImplementedError(msg)
# -> 1262 return self._input_request(
#    1263     str(prompt),
#    1264     self._parent_ident["shell"],
#    1265     self.get_parent("shell"),
#    1266     password=False,
#    1267 )
#
# File ~/.conda/envs/test_env/lib/python3.11/site-packages/ipykernel/kernelbase.py:1305, in Kernel._input_request(self, prompt, ident, parent, password)
#    1302 except KeyboardInterrupt:
#    1303     # re-raise KeyboardInterrupt, to truncate traceback
#    1304     msg = "Interrupted by user"
# -> 1305     raise KeyboardInterrupt(msg) from None
#    1306 except Exception:
#    1307     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# import uuid

def predict_custom_agent_answer(example: dict):
    # config = {"configurable": {"thread_id": str(uuid.uuid4())}}
    state_dict = custom_graph.invoke({"question": example["input"], "steps": []})
    return {"response": state_dict["generation"], "steps": state_dict["steps"]} 

example = {"input": "can you tell me about basaltic rocks"}
response = predict_custom_agent_answer(example)
response
# Out:
# {'response': "Basaltic rocks are a type of igneous rock that is rich in iron and magnesium, with a composition similar to that of the Earth's mantle. They can be classified into different types based on their degree of magmatic differentiation, ranging from primitive basalts to highly differentiated basalts. The table in document (5) lists various basaltic rocks from different regions, including Costa Rica and the GDR, with their respective chemical compositions.",
#  'steps': ['retrieve_documents',
#   'grade_document_retrieval',
#   'generate_answer']}
